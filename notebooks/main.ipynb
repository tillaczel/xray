# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from xray.experiment import Experiment

# %%
K_FOLD = 5
BATCH_SIZE = 512
N_EPOCHS = 500
NUM_WORKERS = 0
LEARNING_RATE = 0.0001

experiment = Experiment()

# %%
experiment.preprocess()

# %%
experiment.vis_data()

# %%
experiment.train(K_FOLD, BATCH_SIZE, N_EPOCHS, NUM_WORKERS, LEARNING_RATE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1          [256, 16, 64, 64]             416
#          MaxPool2d-2          [256, 16, 32, 32]               0
#            Dropout-3          [256, 16, 32, 32]               0
#             Conv2d-4          [256, 32, 32, 32]          12,832
#          MaxPool2d-5          [256, 32, 16, 16]               0
#            Dropout-6          [256, 32, 16, 16]               0
#             Conv2d-7          [256, 64, 16, 16]          51,264
#          MaxPool2d-8            [256, 64, 8, 8]               0
#            Dropout-9            [256, 64, 8, 8]               0
#            Conv2d-10           [256, 128, 8, 8]         204,928
#         MaxPool2d-11           [256, 128, 4, 4]               0
#           Dropout-12           [256, 128, 4, 4]               0
#            Conv2d-13           [256, 256, 4, 4]         819,456
# ...

# %%
experiment.evaluate(BATCH_SIZE, NUM_WORKERS, K_FOLD)
# Out:
# Expert loss: 1.4626%
# Benchmark loss: 9.2964%
# Final loss: 5.3442%
# Ensemble loss: 4.7254%
# Model 0 loss: 4.3751%
# Model 1 loss: 5.0773%
# Model 2 loss: 5.6628%
# Model 3 loss: 5.4793%
# Model 4 loss: 5.6341%
